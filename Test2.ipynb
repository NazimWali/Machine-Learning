# %% [markdown]
# ###  **Submit a single clean notebook containing your work and answers. Call it Your_Last_name.ipynb**
#
#
# ### **Clean, tidy notebooks earn: 5 extra points**

# %% [markdown]
# ### **Question 1 (10 points)**
#
# Consider the following  plots of **four different data sets** showing independent variables along x-axis and dependent variables on y axis. We model  each set of data using linear regression. For each case, pick a most probable estimate of  $r^2$ score (coefficient of determination or square of correlation coefficient) from the list of values: { .92, .85, .66, .3, 0, -3,  1}
#
#
# ![regressions.png](attachment:f5a34733-97e1-4a6a-bc61-9d00771ab5e4.png)

# %% [markdown]
# Your Answer:
#
# For (a), likely $r^2$ =
#
# For (b), likely $r^2$ =
#
# For (c), likely $r^2$ =
#
# For (d), likely $r^2$ =

# %% [markdown]
# ### **Question 2 (20 points)**
#
# **(a)** The given file *fish_weight.csv* contains data on fish dimensions (Height, LengthDiagonal, Width) and Weights. We are interested in modeling fish weights as a linear function of the other variables.
#
# Considering Weight as dependent variable and LengthDiagonal, Height and Width as independent variables, construct a linear regression model of the form:
#
# Weight=A + B \* LengthDiagonal + C \* Height + D \* Width
#
#
# What are the coefficients A, B, C, D and $r^2$ score you get?
#
# Write the coefficients you get:

# %% [markdown]
# A =
#
# B =
#
# C =
#
# D =
#
#
# $r^2$ score =

# %% [markdown]
# **(b)** Now re-construct the model, using only LengthDiagonal and Width as the predictor variables:
#
# Weight=A + B \* LengthDiagonal + C \* Width
#
# What are the coefficients and  𝑟2  score you get?

# %% [markdown]
# A =
#
# B =
#
# C =
#
# $r^2$ score =

# %% [markdown]
# **(c)** Considering $r^2$ in (a) and (b), is there any insight you could possibly draw on the fish weights in relation to the other three variables?

# %% [markdown]
# Your Response:

# %% [markdown]
# ### **Question 3 (Optional - 10 points))**
#
# Using the previous fish data, plot weights as a function of the other three variables
#
#
# ![fishWeights.png](attachment:467f8176-3b12-4e88-a040-8514df7911b4.png)
